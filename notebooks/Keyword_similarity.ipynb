# %% [markdown]
# ## Calculate keyword similarity

# %%
from gensim.models import Word2Vec
from gensim.models import phrases
from pymongo import MongoClient
import pandas as pd
import en_core_web_sm
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from sklearn.externals import joblib
import spacy
import re
import string
from multiprocessing import Pool
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
standard_stopwords = set(list(ENGLISH_STOP_WORDS)+list(stopwords.words('english')))

# %%
client = MongoClient()
db = client.lingbuzz
keywords = db.get_collection('keywords')

# %% [markdown]
# I have a file with all the vocabulary in my corpus and their wordvectors calculated by fastText. I will convert this into a dictionary for easy lookup.

# %%
voc_vectors = {}
with open('voc_vectors.txt', 'rb') as f:
    content = f.readlines()

# %%
for line in content:
    line = line.decode("utf-8").split(" ", 1)
    voc_vectors[line[0]] = {'vector': np.fromstring(line[1].strip(), sep=' '), 'sentenceIDs' : []}

# %%
# the formula used here is wrong. According to the paper it should be the sum of the similarities 
# between the top n most similar words...

# def create_df_rel_cs(vectors, ids):
#     """calculates relative cosine distance between two sentences and returns df with sentenceids and their distance"""
#     cos_sim = cosine_similarity(np.asarray(vectors))
#     sum_cs = np.sum(cos_sim, 1)[0]
#     rel_cs = cos_sim / sum_cs
#     df = pd.DataFrame(rel_cs, index = ids, columns = ids)
#     return df

def create_df_cs(vectors, ids):
    """calculates relative cosine distance between two sentences and returns df with sentenceids and their distance"""
    cos_sim = cosine_similarity(np.asarray(vectors))
    df = pd.DataFrame(cos_sim, index = ids, columns = ids)
    return df

# %% [markdown]
# ## Keyword similarity
#
# Calculate similarities and set similarity threshold.

# %%
kwords = []
keyword_vec = []
for entry in voc_vectors:
    if entry not in standard_stopwords:
        kwords.append(entry)
        keyword_vec.append(voc_vectors[entry]['vector'])

# %%
keyword_similarities = create_df_cs(keyword_vec, kwords)

# %%
keyword_similarities.head()
# Out:
#             analytic  passives     czech   ludmila  veselovská      petr  \
# analytic    1.000000  0.327499  0.136207  0.118241    0.201351  0.161108
# passives    0.327499  1.000000  0.071210  0.030514    0.099147  0.060225
# czech       0.136207  0.071210  1.000000  0.473511    0.636377  0.609529
# ludmila     0.118241  0.030514  0.473511  1.000000    0.584787  0.578897
# veselovská  0.201351  0.099147  0.636377  0.584787    1.000000  0.614322
#
#             introduction  defining   problem      like    ...         aame  \
# analytic        0.318767  0.409865  0.340559  0.178999    ...     0.066546
# passives        0.174664  0.196529  0.269647  0.322238    ...     0.181510
# czech           0.162274  0.229002  0.172338  0.134997    ...     0.117394
# ludmila         0.099382  0.091970  0.133546  0.058865    ...     0.063211
# veselovská      0.121936  0.171760  0.171601  0.141154    ...     0.113671
#
#                  rsp     aitem     bitem  diagonals  lpassives  npassives  \
# analytic    0.091149  0.200329  0.139000   0.391649   0.331104   0.341165
# passives    0.193179  0.215486  0.189093   0.283702   0.851886   0.869041
# czech       0.081306  0.090537  0.075196   0.084607   0.078563   0.104193
# ludmila    -0.007784  0.037557  0.120576   0.142093   0.037525   0.033915
# veselovská  0.093452  0.252779  0.137046   0.155786   0.124676   0.132634
#
#                 boty   kingnom      zmar
# analytic    0.159959  0.107133  0.120273
# passives    0.058934  0.143894  0.155694
# czech       0.315703  0.200767  0.312162
# ludmila     0.324045  0.244663  0.250185
# veselovská  0.320539  0.291361  0.342530
#
# [5 rows x 50972 columns]

# %%
synonyms = []
headers = list(keyword_similarities.columns)
for i, row in keyword_similarities.head(20).iterrows():
    most_similar = sorted(row.drop(i))[-10:]
    columns = list(row.isin(most_similar))
    synonyms.append((i, list(compress(headers, columns)), most_similar))

# %% [markdown]
# 0.6 seems like a reasonable threshold: words with a similarity higher than this number will be included in the most-similar entry in the keyword database.

# %% [markdown]
# Very high similarity are related words, true synonyms have lower similarity. For list of related keywords: eliminate stopwords.

# %%
from itertools import compress
synonyms = {}
headers = list(keyword_similarities.columns)
for i, row in keyword_similarities.iterrows():
    most_similar = [x for x in row.drop(i) if x >= 0.635]
    columns = list(row.isin(most_similar))
    synonyms[i] =  list(compress(headers, columns))

# %%
synonyms['czech']
# Out:
# ['veselovská', 'prague', 'brno', 'praha', 'olomouc', 'ladislav', 'slovak']

# %%
joblib.dump(synonyms, 'similar_keywords')
# Out:
# ['similar_keywords']

# %%
similar_keywords = joblib.load('similar_keywords')

# %%
voc_vectors_dict = joblib.load('voc_vectors_dict')

# %%
id_keywords = {}
for keyword in keywords.find():
    id_keywords[keyword['word']]=keyword['_id']

for k, v in similar_keywords.items():
    keyword_ids = [id_keywords[kw] for kw in v]
    keywords.update_one({'word': k}, {'$set': {'similar_words': keyword_ids}})

# %%
keywords.find().count()
# Out:
# 51301

# %%
for doc in keywords.find():
    keywords.update_one({'_id': doc['_id']}, {'$set': {'frequency': len(doc['sentenceIDs'])} })

# %%
frequencies['islands']
# Out:
# 733

# %%
for doc in papers.find({'paper': {'$exists': True}})[:5]:
    print(doc['authors'], doc['updated_keywords'])
# Out:
# ['Lida Veselovska'] ['czech', 'passives', 'passive', 'vs', 'past_participles', 'czech', 'clitics', 'past', 'czech', 'auxiliary', 'grammatical', 'morphemes', 'instrumental', 'case', 'postsyntactic', 'insertion', 'postsyntactic', 'derivation', 'semantics', 'morphology', 'syntax', 'morphology', 'syntax']
# ['Lida Veselovska'] ['czech', 'dp', 'universal', 'dp', 'determiners', 'functional', 'domain', 'word_order', 'in', 'dps', 'semantics', 'of', 'dp', 'modifiers', 'of', 'n', 'semantics', 'morphology', 'syntax']
# ['Philippe Schlenker'] ['sign_language', 'strong', 'pronouns', 'pointing', 'focus', 'semantics', 'morphology', 'syntax']
# ['Asia Pietraszko'] ['syntax', 'morphology', 'extended_projections', 'selection', 'agreement', 'multiverbal', 'constructions', 'auxiliaries', 'light_verbs', 'ndebele', 'bantu']
# ['Hadas Kotek', 'Matthew Barros'] ['sluicing', 'ellipsis', 'licensing', 'pairlist', 'readings', 'scope', 'parallelism', 'semantics', 'syntax']

# %%
papers = db.get_collection('papers')
sentences = db.get_collection('sentences')

# %%
a = [lambda doc: doc['_id'] for doc in sentences.find({}, {'_id': 1}).sort([('score',-1)]).limit(1)]

# %%
q = ['wrote', 'syntax']
answer = 'These are some papers you might want to read: \n\n'
for w in q:
    for candidate in papers.find({'updated_keywords': w}):
        answer += candidate['title'] + ', by '+ ', '.join(c for c in candidate['authors']) + '\n'
        answer += 'You can download the paper here: ling.auf.net/' + candidate['url'] + '\n\n'
print(answer)
# Out:
# wrote
# syntax
# These are some papers you might want to read:
#
# The clause-mate condition on resumption: Evidence from Kaqchikel, by Yusuke Imanishi
# You can download the paper here: ling.auf.net//lingbuzz/003606
#
# The Preliminary Material of 'Natural Language and Possible Minds: How Language Uncovers the Cognitive Landscape of Nature', by Prakash Mondal
# You can download the paper here: ling.auf.net//lingbuzz/003607
#
# Analytic Passives in Czech, by Lida Veselovska
# You can download the paper here: ling.auf.net//lingbuzz/003608
#
# Stylistic Fronting in corpora, by Halldor Armann Sigurdsson
# You can download the paper here: ling.auf.net//lingbuzz/002635
#
# Topicality in Icelandic: Null arguments and Narrative Inversion, by Halldor Armann Sigurdsson
# You can download the paper here: ling.auf.net//lingbuzz/003611
#
# The Universal DP Analysis in Articleless Languages: A Case Study in Czech, by Lida Veselovska
# You can download the paper here: ling.auf.net//lingbuzz/003609
#
# Proxy control: extending the typology of control in grammar, by Aaron Doliana, Sandhya Sundaresan
# You can download the paper here: ling.auf.net//lingbuzz/003612
#
# POSSESSIVES AND THEIR EQUIVALENTS IN ENGLISH AND CZECH: A COMPARATIVE STUDY, by Lida Veselovska
# You can download the paper here: ling.auf.net//lingbuzz/003610
#
# Strong Pronominals ASL and LSF (squib), by Philippe Schlenker
# You can download the paper here: ling.auf.net//lingbuzz/003613
#
# Blocking and Paradigm Gaps, by Itamar Kastner, Vera Zu
# You can download the paper here: ling.auf.net//lingbuzz/002394
#
# (Im)possible Intensionality (or why Deep Double Objects underlie all Alternations), by Dominique Sportiche
# You can download the paper here: ling.auf.net//lingbuzz/003479
#
# Non-possessive person in the nominal domain, by Georg Höhn
# You can download the paper here: ling.auf.net//lingbuzz/003618
#
# Investigating Variation in Island Effects: A Case Study of Norwegian Wh-Extraction, by Dave Kush, Terje Lohndal, Jon Sprouse
# You can download the paper here: ling.auf.net//lingbuzz/003617
#
# Inflectional Dependencies. A study of complex verbal expressions in Ndebele, by Asia Pietraszko
# You can download the paper here: ling.auf.net//lingbuzz/003619
#
# Locative Shift, by Philippe Schlenker
# You can download the paper here: ling.auf.net//lingbuzz/003482
#
# Lexicalist vs. exoskeletal approaches to language mixing, by Maren Berg Grimstad, Brita Ramsevik Riksem, Terje Lohndal, Tor Anders Aafarli
# You can download the paper here: ling.auf.net//lingbuzz/003621
#
# On the Symmetry of Case in Conjunction, by Philipp Weisser
# You can download the paper here: ling.auf.net//lingbuzz/003603
#
# Composite A/A'-movement: Evidence from English tough-movement, by Nicholas Longenbaugh
# You can download the paper here: ling.auf.net//lingbuzz/003604
#
# Definiteness determined by syntax: A case study in Tagalog, by James N. Collins
# You can download the paper here: ling.auf.net//lingbuzz/003570
#
# Multiple Sluicing, Scope, and Superiority: Consequences for Ellipsis Identity, by Hadas Kotek, Matthew Barros
# You can download the paper here: ling.auf.net//lingbuzz/003549
#
# Little words don’t lie: X’ have initial X0, by Joseph Emonds
# You can download the paper here: ling.auf.net//lingbuzz/003605
#
# Agreement stacking and topic oriented agreement: how to agree with adverbs, gerunds and prepositions , by Roberta D'Alessandro
# You can download the paper here: ling.auf.net//lingbuzz/003563
#
# On “Sluicing” with apparent massive pied-piping, by Klaus Abels
# You can download the paper here: ling.auf.net//lingbuzz/003585
#
# On the syntax of multiple sluicing and what it tells us about wh scope taking, by Klaus Abels, Veneeta Dayal
# You can download the paper here: ling.auf.net//lingbuzz/003584
#
# Core intentional features in the syntactic computation: deriving the position of the subject in Spanish, by Ana Ojea
# You can download the paper here: ling.auf.net//lingbuzz/003590
#
# Copying and Resolution in South Slavic and South Bantu Conjunct Agreement, by Andrew Ira Nevins
# You can download the paper here: ling.auf.net//lingbuzz/003589
#
# Quantifier Domain Restriction as Ellipsis, by Chris Collins
# You can download the paper here: ling.auf.net//lingbuzz/002616
#
# Disentangling Two Distinct Notions of NEG Raising, by Chris Collins, Paul Postal
# You can download the paper here: ling.auf.net//lingbuzz/003595
#
# Escape from Silent Syntax, by Yuta Sakamoto
# You can download the paper here: ling.auf.net//lingbuzz/003573
#
# Parametrizing the Timing of Transfer in Japanese and English and its Consequences, by Ryoichiro Kobayashi
# You can download the paper here: ling.auf.net//lingbuzz/003581
#
# On Some Symmetric Constituents in Japanese, by Ryoichiro Kobayashi
# You can download the paper here: ling.auf.net//lingbuzz/003582
#
# Functionally Equivalent Variants in a Non-standard Variety and Their Implications for Universal Grammar: A Spontaneous Speech Corpus, by Evelina Leivada, Elena Papadopoulou, Natalia Pavlou
# You can download the paper here: ling.auf.net//lingbuzz/003583
#
# Multiple facets of constructional Arabic Gender and ‘functional universalism’ in the DP*, by Abdelkader Fassi Fehri
# You can download the paper here: ling.auf.net//lingbuzz/003529
#
# When person agreement and binding go their separate ways, by Maria Polinsky
# You can download the paper here: ling.auf.net//lingbuzz/003532
#
# Processing Tenses for the Living and the Dead: A Psycholinguistic Investigation of Lifetime Effects in Tensed and Tenseless Languages, by Sherry Yong Chen
# You can download the paper here: ling.auf.net//lingbuzz/repo/semanticsArchive/article/001631
#
# Mandarin associative plural -men and NPs with -men , by Julie Jiang
# You can download the paper here: ling.auf.net//lingbuzz/003074
#
# Scrambling(s) + Clitics = CLLD (The case of French), by Nikos Angelopoulos, Dominique Sportiche
# You can download the paper here: ling.auf.net//lingbuzz/003486
#
# Agreement syncretisation and the loss of null subjects: quantificational models for Medieval French, by Alexandra Simonenko, Benoît Crabbé, Sophie Prévost
# You can download the paper here: ling.auf.net//lingbuzz/003491
#
# On the Implicit Argument in the Short Passive, by Chris Collins
# You can download the paper here: ling.auf.net//lingbuzz/003492
#
# Against 'Tanglewood' by focus movement: a reply to Erlewine and Kotek (to appear), by Nicholas Longenbaugh, Itai Bassi
# You can download the paper here: ling.auf.net//lingbuzz/003494
#
# Do You Really Mean It? Linking Lexical Semantic Profiles and the Age of Acquisition for the English Passive, by Emma Nguyen, Lisa Pearl
# You can download the paper here: ling.auf.net//lingbuzz/003496
#
# Temporal/locative inversion in Arabic, by Marwan Jarrah
# You can download the paper here: ling.auf.net//lingbuzz/003375
#
# Templatic morphology as an emergent property: Roots and functional heads in Hebrew, by Itamar Kastner
# You can download the paper here: ling.auf.net//lingbuzz/003103
#
# Revolutionary New Ideas Appear Infrequently, by Robert Berwick
# You can download the paper here: ling.auf.net//lingbuzz/003471
#
# Back to the Future: Non-generation, filtration, and the heartbreak of interface-driven minimalism, by Omer Preminger
# You can download the paper here: ling.auf.net//lingbuzz/003447
#
# Strict and non-strict negative concord in Hungarian: A unified analysis, by Anna Szabolcsi
# You can download the paper here: ling.auf.net//lingbuzz/003498
#
# A dual theory of roots: Evidence from gender-marking languages, by Ivona Kucerova, Adam Szczegielniak
# You can download the paper here: ling.auf.net//lingbuzz/003506
#
# On the unavailability of argument ellipsis in Kaqchikel, by Michael Yoshitaka Erlewine, Theodore Levin
# You can download the paper here: ling.auf.net//lingbuzz/003503
#
# Representation and Processing of the Inflected Infinitive in Brazilian Portuguese: an eye-tracking study, by Marcello Modesto, Marcus Maia
# You can download the paper here: ling.auf.net//lingbuzz/003389
#
# Generative Grammar and the Faculty of Language: Insights, Questions, and Challenges, by Noam Chomsky, Ángel J. Gallego, Dennis Ott
# You can download the paper here: ling.auf.net//lingbuzz/003507
#
# The role of incremental parsing in syntactically conditioned word learning, by Jeffrey Lidz, Aaron Steven White, Rebecca Baier
# You can download the paper here: ling.auf.net//lingbuzz/003145
#
# AxParts and Case in Complex PPs: Microvariation in Italian dialects, by Jacopo Garzonio, Silvia Rossi
# You can download the paper here: ling.auf.net//lingbuzz/003515
#
# Gestural Grammar, by Philippe Schlenker
# You can download the paper here: ling.auf.net//lingbuzz/003497
#
# What makes the imperative clause type autonomous. A comparative study in a modular perspective, by Christer Platzack, Inger Rosengren
# You can download the paper here: ling.auf.net//lingbuzz/003516
#
# Nominal ellipses, by Andrés Saab
# You can download the paper here: ling.auf.net//lingbuzz/002216
#
# The morphosyntax of exhaustive focus: A view from Awing (Grassfields Bantu), by Henry Fominyam, Radek Simik
# You can download the paper here: ling.auf.net//lingbuzz/003291
#
# Syntactic effects of the morphological status of the negative marker: negative imperatives vs. negative gerunds, by Alexandru Nicolae
# You can download the paper here: ling.auf.net//lingbuzz/003387
#
# Categorization as noun construction. Gender, number, and entity types., by Paolo Acquaviva
# You can download the paper here: ling.auf.net//lingbuzz/003317
#
# Forest quickstart guide, by Guido Vanden Wyngaerd
# You can download the paper here: ling.auf.net//lingbuzz/003391
#
# Passive se in Romanian and Spanish: a subject cycle, by Jonathan MacDonald, Matthew Maddox
# You can download the paper here: ling.auf.net//lingbuzz/003366
#
# ONLY: An NPI-licenser and NPI-unlicenser, by Yimei Xiang
# You can download the paper here: ling.auf.net//lingbuzz/003393
#
# Subject/Object Asymmetries in Northern Iroquoian Noun Incorporation, by Michael Barrie
# You can download the paper here: ling.auf.net//lingbuzz/003394
#
# Case decomposition meets dependent-case theories, by Stanislao Zompi'
# You can download the paper here: ling.auf.net//lingbuzz/003421
#
# Semantic information and the syntax of propositional attitude verbs, by Aaron Steven White, Valentine Hacquard, Jeffrey Lidz
# You can download the paper here: ling.auf.net//lingbuzz/003510
#
# A unifying analysis of Turkish relative clause, by Ercan Solak, Razieh Ehsani
# You can download the paper here: ling.auf.net//lingbuzz/003531
#
# The achievements of Generative Syntax: a time chart, by Roberta D'Alessandro
# You can download the paper here: ling.auf.net//lingbuzz/003392
#
# Semantics and Morphosyntactic Variation:  Qualities and the Grammar of Property Concepts, by Itamar Francez, Andrew J. Koontz-Garboden
# You can download the paper here: ling.auf.net//lingbuzz/003396
#
# Splitting up the comparative: evidence from Czech, by Karen De Clercq, Guido Vanden Wyngaerd
# You can download the paper here: ling.auf.net//lingbuzz/003171
#
# The formal properties of non paradigmatic SE, by Javier Ormazabal, Juan Romero
# You can download the paper here: ling.auf.net//lingbuzz/003402
#
# An Argument for Zwart’s Merge. Quotation as a Challenge for Feature-Driven Phases., by Jan Wiślicki
# You can download the paper here: ling.auf.net//lingbuzz/003399
#
# Minimalist Semantics and Pre-Linguistic Intelligence, by Sasson  Margaliot
# You can download the paper here: ling.auf.net//lingbuzz/003409
#
# Ma non era rosso? (But wasn’t it red?): On counter-expectational questions in Italian, by Alessandra Giorgi
# You can download the paper here: ling.auf.net//lingbuzz/003412
#
# Prosodic smothering in Macedonian and Kaqchikel, by Ryan Bennett, Boris Harizanov, Robert Henderson
# You can download the paper here: ling.auf.net//lingbuzz/003413
#
# SYNTACTIC ARCHAISMS PRESERVED IN A CONTEMPORARY ROMANCE VARIETY: INTERPOLATION AND SCRAMBLING IN OLD ROMANIAN AND ISTRO-ROMANIAN, by Alexandru Nicolae, Adina DRAGOMIRESCU
# You can download the paper here: ling.auf.net//lingbuzz/003415
#
# Relative clauses and CP nominalization in Ndebele, by Asia Pietraszko
# You can download the paper here: ling.auf.net//lingbuzz/003273
#
# Modeling syntactic acquisition, by Lisa Pearl
# You can download the paper here: ling.auf.net//lingbuzz/003416
#
# Case Syncretism in Russian, Polish and Czech ATB Constructions, by Petr Biskup
# You can download the paper here: ling.auf.net//lingbuzz/003554
#
# Formal lexical entries for French Clitics: PF dissociations of single marked features, by Joseph Emonds
# You can download the paper here: ling.auf.net//lingbuzz/003578
#
# Expression of information structure in West Slavic: Modeling the impact of prosodic and word order factors, by Radek Simik, Marta Wierzba
# You can download the paper here: ling.auf.net//lingbuzz/003304
#
# Object movement (object shift and scrambling), by Hans Broekhuis
# You can download the paper here: ling.auf.net//lingbuzz/003217
#
# The Final-over-Final Condition and Particles, by Theresa Biberauer
# You can download the paper here: ling.auf.net//lingbuzz/003313
#
# Intonation, yes and no, by Daniel Goodhue, Michael Wagner
# You can download the paper here: ling.auf.net//lingbuzz/003082
#
# On Split Affectivity in Chinese, by Wei-Tien Dylan Tsai
# You can download the paper here: ling.auf.net//lingbuzz/003316
#
# Why the null complementizer is special in the English that-trace effect, by Michael Yoshitaka Erlewine
# You can download the paper here: ling.auf.net//lingbuzz/002029
#
# Building negative events, by Antonio Fábregas, Raquel González-Rodríguez
# You can download the paper here: ling.auf.net//lingbuzz/003321
#
# Fragment answers: a superlative argument, by Zheng Shen
# You can download the paper here: ling.auf.net//lingbuzz/003323
#
# Exceptional Movement from/into the Criterial Position, by Mayumi Hosono
# You can download the paper here: ling.auf.net//lingbuzz/003324
#
# Adjunct Control Depends on Voice, by Idan Landau
# You can download the paper here: ling.auf.net//lingbuzz/003322
#
# Main clause syntax and the labeling problem in syntactic bootstrapping, by Aaron Steven White, Valentine Hacquard, Jeffrey Lidz
# You can download the paper here: ling.auf.net//lingbuzz/002917
#
# Synchronic variation and diachronic change in Dutch two-verb clusters, by Marieke Olthof, Maud Westendorp, Jelke Bloem, Fred Weerman
# You can download the paper here: ling.auf.net//lingbuzz/003328
#
# The Semantic Proto-Role Linking Model, by Aaron Steven White, Kyle Rawlins, Benjamin Van Durme
# You can download the paper here: ling.auf.net//lingbuzz/003327
#
# How real are adjective order constraints? Multiple prenominal adjectives at the grammatical interfaces, by Sven Kotowski, Holden Härtl
# You can download the paper here: ling.auf.net//lingbuzz/003218
#
# Idioms: Phasehood and Projection, by Will Harwood, Marko Hladnik, Sterre Leufkens, Tanja Temmerman, Norbert Corver, Jeroen van Craenenbroeck
# You can download the paper here: ling.auf.net//lingbuzz/002951
#
# Reduced relatives and extended phases: a phase-based analysis of the inflectional restrictions on English reduced relative clauses, by Will Harwood
# You can download the paper here: ling.auf.net//lingbuzz/002867
#
# Testing the Processing Hypothesis of word order variation using a probabilistic language model, by Jelke Bloem
# You can download the paper here: ling.auf.net//lingbuzz/003252
#
# Icelandic Articles and Anaphora - The Free Article can be Strong!, by Alexander Pfaff
# You can download the paper here: ling.auf.net//lingbuzz/003371
#
# The prepositional passive in Lexical Functional Grammar, by Jamie Y. Findlay
# You can download the paper here: ling.auf.net//lingbuzz/003407
#
# On the Structure of Toponyms, by Francesco-Alessio Francesco Ursini
# You can download the paper here: ling.auf.net//lingbuzz/003417
#
# Arity operations in Hindi: A Lexicon-Syntax Interface Perspective, by Richa Srishti
# You can download the paper here: ling.auf.net//lingbuzz/003546
#
# Framesetters and the micro-variation of subject-initial V2, by Ciro Greco, Liliane Haegeman
# You can download the paper here: ling.auf.net//lingbuzz/003226
#
# Formal and semantic agreement in syntax: A dual feature approach, by Susi Wurmbrand
# You can download the paper here: ling.auf.net//lingbuzz/003233
#
# On Verb Second and Clitic Second, by Zeljko Boskovic
# You can download the paper here: ling.auf.net//lingbuzz/003234
#
# Towards a unified theory of wh-in-situ and islands, by Andrew Murphy
# You can download the paper here: ling.auf.net//lingbuzz/003236
#
# Self and Only: A Comparative Study of Reflexive Adverbials in Squliq Atayal and Mandarin Chinese, by Wei-Tien Dylan Tsai
# You can download the paper here: ling.auf.net//lingbuzz/003238
#
# What is Suppletive Allomorphy? On 'went' and on '*goed' in English, by Richard Kayne
# You can download the paper here: ling.auf.net//lingbuzz/003241
#
# Prosody as an argument for a layered left periphery, by Karen De Clercq
# You can download the paper here: ling.auf.net//lingbuzz/003240
#
# Even doesn't move but associates into traces: A reply to Nakanishi 2012, by Michael Yoshitaka Erlewine
# You can download the paper here: ling.auf.net//lingbuzz/003132
#
# Notes on insertion in Distributed Morphology and Nanosyntax, by Pavel Caha
# You can download the paper here: ling.auf.net//lingbuzz/002855
#
# Projecting attitudes, by Aaron Steven White, Valentine Hacquard, Jeffrey Lidz
# You can download the paper here: ling.auf.net//lingbuzz/002701
#
# Bare Nominal Adjuncts, by Michael Barrie, Isaiah Yoo
# You can download the paper here: ling.auf.net//lingbuzz/003133
#
# Sentential Oddities and the Mass-Count Distinction: Do colourful ideas sleep calmly?, by Alan Bale
# You can download the paper here: ling.auf.net//lingbuzz/003102
#
# Puzzles and mysteries in the origins of language, by Chris Knight
# You can download the paper here: ling.auf.net//lingbuzz/003141
#
# Levels of Linguistic Acts and the Semantics of Saying and Quoting , by Friederike Moltmann
# You can download the paper here: ling.auf.net//lingbuzz/003140
#
# Dependent case without case: Evidence from the Yimas clitic system, by Michelle Yuan
# You can download the paper here: ling.auf.net//lingbuzz/003134
#
# Normality at the boundary between word-formation and syntax, by Holden Härtl
# You can download the paper here: ling.auf.net//lingbuzz/002670
#
# Null subjects in Finnish and the typology of pro-drop, by Anders Holmberg
# You can download the paper here: ling.auf.net//lingbuzz/003138
#
# Neg-Raising and Neg movement, by Paul Crowley
# You can download the paper here: ling.auf.net//lingbuzz/repo/semanticsArchive/article/001587
#
# Explaining DPs vs. CPs without syntax, by Patrick D. Elliott
# You can download the paper here: ling.auf.net//lingbuzz/003128
#
# Gender Mismatches and Ellipsis in Cayuga, by Michael Barrie
# You can download the paper here: ling.auf.net//lingbuzz/003149
#
# On the (un)interpretability of phi-agreement, by Milan Rezac
# You can download the paper here: ling.auf.net//lingbuzz/003165
#
# Explaining Bobaljik’s Root Suppletion Generalization as an instance of the Adjacency Condition (and beyond), by Pavel Caha
# You can download the paper here: ling.auf.net//lingbuzz/003168
#
# On the double-headed analysis of “Headless” relative clauses, by Guglielmo Cinque
# You can download the paper here: ling.auf.net//lingbuzz/003224
#
# (Grammatical) gender troubles and the gender of pronouns, by Phoevos Panagiotidis
# You can download the paper here: ling.auf.net//lingbuzz/003231
#
# IN FAVOR OF CONTRASTIVE TOPIC PHRASE IN NORTH HAIL ARABIC LEFT PERIPHERY: EVIDENCE FROM THE DISCOURSE PARTICLE TARA , by Murdhy Alshamari
# You can download the paper here: ling.auf.net//lingbuzz/003377
#
# Clausal Ellipsis and Case (Mis)Matching in Icelandic, by Jim Wood, Matthew Barros, Einar Sigurðsson
# You can download the paper here: ling.auf.net//lingbuzz/003040
#
# Low sentence-final particles in Mandarin Chinese and the Final-over-Final Constraint, by Michael Yoshitaka Erlewine
# You can download the paper here: ling.auf.net//lingbuzz/002495
#
# Vocabulary insertion and locality: Verb suppletion in Northern Paiute, by Maziar Toosarvandani
# You can download the paper here: ling.auf.net//lingbuzz/002937
#
# Fragment questions: Deleting question items, by Haoze Li
# You can download the paper here: ling.auf.net//lingbuzz/003042
#
# Processing Relative Clauses in Chinese: Commentary on Paper by F. Hsiao and E. Gibson, by Hueseyin Uysal
# You can download the paper here: ling.auf.net//lingbuzz/003047
#
# Pronominal inflection and NP ellipsis in German, by Andrew Murphy
# You can download the paper here: ling.auf.net//lingbuzz/003049
#
# Çincede ilgi tümceciklerinin işlenmesi: F. Hsiao and E. Gibson’un çalışması üzerine bir eleştiri, by Hueseyin Uysal
# You can download the paper here: ling.auf.net//lingbuzz/003048
#
# Subject Blocking in Verbal Idioms: Evidence from Passive-Like Constructions in Icelandic, by Anton Ingason, Einar Sigurðsson, Jim Wood
# You can download the paper here: ling.auf.net//lingbuzz/003051
#
# Memorization and the morphology-syntax divide: A cross-linguistic investigation, by Marcel Schlechtweg, Holden Härtl
# You can download the paper here: ling.auf.net//lingbuzz/002770
#
# Counting banana trees in Ch’ol: Exploring the syntax and semantics of sortal classifiers, by Alan Bale, Jessica Coon, Nicolás Arcos López
# You can download the paper here: ling.auf.net//lingbuzz/003057
#
# Finiteness contrasts without Tense? A view from Mandarin Chinese, by Thomas Grano
# You can download the paper here: ling.auf.net//lingbuzz/003056
#
# Steps towards a Generative Theory of Dance Cognition, by Isabelle Charnavel
# You can download the paper here: ling.auf.net//lingbuzz/003137
#
# The morphosyntax of adverbs in Shupamem, by Abass Yiagnigni
# You can download the paper here: ling.auf.net//lingbuzz/003174
#
# Quantification in American Sign Language, by Natasha Abner, Ronnie Wilbur
# You can download the paper here: ling.auf.net//lingbuzz/003190
#
# Syntactic Categorization in Sign Languages, by Natasha Abner
# You can download the paper here: ling.auf.net//lingbuzz/003189
#
# Three kinds of locative preposing, by Chris Bruno
# You can download the paper here: ling.auf.net//lingbuzz/003596
#
# Suffixation under structural adjacency: The case of Icelandic the-support, by Anton Ingason
# You can download the paper here: ling.auf.net//lingbuzz/003060
#
# How to say no in English and Chinese, by Anders Holmberg, Meng-Jung Wu
# You can download the paper here: ling.auf.net//lingbuzz/003063
#
# Raising to ergative: remarks on applicatives of unaccusatives, by Amy Rose Deal
# You can download the paper here: ling.auf.net//lingbuzz/003024
#
# Two ways of encoding location in Greek: Locative applicatives and prepositions, by Evangelia Daskalaki, Marios Mavrogiorgos
# You can download the paper here: ling.auf.net//lingbuzz/002975
#
# Stripping and topless complements, by Susi Wurmbrand
# You can download the paper here: ling.auf.net//lingbuzz/001779
#
# Tool Grammar: Re-factoring the Generative Program A pervasive action dimension for linguistic descriptions, theories and models, by Larry Smith
# You can download the paper here: ling.auf.net//lingbuzz/002836
#
# On the limits of variation in West-Germanic verb clusters. Evidence from displaced morphology and extraposition for the existence of clusters with 213 order, by Martin Salzmann
# You can download the paper here: ling.auf.net//lingbuzz/002939
#
# Displaced morphology in German – Evidence for post-syntactic morphology, by Martin Salzmann
# You can download the paper here: ling.auf.net//lingbuzz/002828
#
# Syntactic Identity in Ellipsis, and Deviations Therefrom: The case of copular sources in sluicing, by Matthew Barros
# You can download the paper here: ling.auf.net//lingbuzz/002940
#
# The fundamental left-right asymmetry in the Germanic verb cluster, by Klaus Abels
# You can download the paper here: ling.auf.net//lingbuzz/002613
#
# Deep properties of a surface anaphor: on the contextual restriction of sluicing sites, by Troy Messick, Andrés Saab, Luis Vicente
# You can download the paper here: ling.auf.net//lingbuzz/002507
#
# Evaluation, use, and refinement of knowledge 	representations through acquisition modeling, by Lisa Pearl
# You can download the paper here: ling.auf.net//lingbuzz/002776
#
# Cuestiones de Localidad. Notas de clase (Locality issues. Lecture notes), by Andrés Saab
# You can download the paper here: ling.auf.net//lingbuzz/002941
#
# Syntax of Dutch. Verbs and Verb Phrases, volume 3 (sample on adverbial phrases), by Hans Broekhuis, Norbert Corver
# You can download the paper here: ling.auf.net//lingbuzz/002945
#
# On the relation of Middle English to West Saxon, by Joe Emonds, Jan-Terje Faarlund
# You can download the paper here: ling.auf.net//lingbuzz/002944
#
# An argument against the syntactic nature of verb movement, by Jan-Wouter Zwart
# You can download the paper here: ling.auf.net//lingbuzz/002950
#
# On the interpretation of reflexive pronouns, by Alanah McKillen
# You can download the paper here: ling.auf.net//lingbuzz/002952
#
# Structure, use, and syntactic ecology in language obsolescence, by David Adger
# You can download the paper here: ling.auf.net//lingbuzz/002957
#
# The Sticky Reading: VP Ellipsis Without Parallel Binding, by Patrick D. Elliott, Andreea Nicolae, Yasutada Sudo
# You can download the paper here: ling.auf.net//lingbuzz/002900
#
# Successive-cyclic case assignment: Korean nominative-nominative case-stacking, by Theodore Levin
# You can download the paper here: ling.auf.net//lingbuzz/002989
#
# Realizing morphemes in the Icelandic noun phrase, by Anton Ingason
# You can download the paper here: ling.auf.net//lingbuzz/002988
#
# Language evolution: Insisting on making it a mystery or turning it into a problem?, by Pedro Tiago Martins, Cedric Boeckx
# You can download the paper here: ling.auf.net//lingbuzz/003000
#
# A Response to Sauerland, by Daniel Everett
# You can download the paper here: ling.auf.net//lingbuzz/002857
#
# Variation and change in the Romance faire-par causative, by Michelle Sheehan, Sonia Cyrino
# You can download the paper here: ling.auf.net//lingbuzz/002856
#
# Pseudogapping as pseudo-VP ellipsis, by Yusuke Kubota, Bob Levine
# You can download the paper here: ling.auf.net//lingbuzz/002504
#
# The Unicity of 'There' and the Definiteness Effect, by Richard Kayne
# You can download the paper here: ling.auf.net//lingbuzz/002858
#
# Postsyntactic Reordering in the Mari Nominal Domain - Evidence from Suspended Affixation, by Philipp Weisser
# You can download the paper here: ling.auf.net//lingbuzz/002859
#
# The se-ra alternation in Spanish subjunctive, by Matías Guzmán Naranjo
# You can download the paper here: ling.auf.net//lingbuzz/002301
#
# Ditransitives, by Heidi Harley, Shigeru Miyagawa
# You can download the paper here: ling.auf.net//lingbuzz/002870
#
# An implicit projected argument in Spanish impersonal and passive se constructions∗, by Jonathan MacDonald
# You can download the paper here: ling.auf.net//lingbuzz/002872
#
# On the interaction of P-stranding and Sluicing in Bulgarian, by Klaus Abels
# You can download the paper here: ling.auf.net//lingbuzz/002896
#
# Udmurt as an OV language and Finnish as a VO language, by Andreas Schmidt
# You can download the paper here: ling.auf.net//lingbuzz/002907
#
# Language Pathology, by Ianthi M. Tsimpli, Maria Kambanaros, Kleanthes K. Grohmann
# You can download the paper here: ling.auf.net//lingbuzz/003009
#
# The 'Imperfective' in Attributive Clauses in Korean as a Window into the Evidential Past and the Metaphysical Future, by Min-Joo Kim
# You can download the paper here: ling.auf.net//lingbuzz/002780
#
# On the semantics and syntax of Persian 'become', by Negin Ilkhanipour, Ayaka Sugawara
# You can download the paper here: ling.auf.net//lingbuzz/003245
#
# Probing the nature of the Final-over-Final Constraint: the perspective from adpositions, by Theresa Biberauer
# You can download the paper here: ling.auf.net//lingbuzz/003314
#
# NEG-Raising in crosslinguistic perspective, by Marie-Luise Popp
# You can download the paper here: ling.auf.net//lingbuzz/003385
#
# Middle English V2: Compatible with a North Germanic source?, by Joseph Emonds
# You can download the paper here: ling.auf.net//lingbuzz/003579
#
# Breaking Opaque Domains, by atakan ince
# You can download the paper here: ling.auf.net//lingbuzz/002861
#
# Locatives in Shona and Luganda, by Pavel Caha, Marina Pantcheva
# You can download the paper here: ling.auf.net//lingbuzz/002220
#
# SEMANTIC GENDER DIVERSITY AND ITS ARCHITECTURE IN THE GRAMMAR OF ARABIC, by Abdelkader Fassi Fehri
# You can download the paper here: ling.auf.net//lingbuzz/002862
#
# Romanian tough-constructions and multi-headed constituents, by Ion Giurgea
# You can download the paper here: ling.auf.net//lingbuzz/002868
#
# Stress-by-Reduplication in Los Silos Spanish, by Alejo Alcaraz
# You can download the paper here: ling.auf.net//lingbuzz/002747
#
# Interactions of gender and number agreement: Evidence from Bosnian/Croatian/Serbian, by Zorica Puskar
# You can download the paper here: ling.auf.net//lingbuzz/002750
#
# Syntax, Semantics and the Language of Thought: Preliminaries, by Annabel Cormack, Neil Smith
# You can download the paper here: ling.auf.net//lingbuzz/002753
#
# Epistemic bias in embedded polar questions, by Hans Van De Koot, Harris Constantinou, Yan Zhang
# You can download the paper here: ling.auf.net//lingbuzz/002772
#
# The semantic inertness of medial right-node raising in Japanese, by Shuichi Yatabe
# You can download the paper here: ling.auf.net//lingbuzz/002778
#
# Locality domains in syntax: Evidence from sentence processing, by Stefan Keine
# You can download the paper here: ling.auf.net//lingbuzz/002473
#
# The A-/A'-distinction as an epiphenomenon, by Ken Safir
# You can download the paper here: ling.auf.net//lingbuzz/002798
#
# Delayed Valuation: a reanalysis of "upwards" complementizer agreement and the mechanics of Case, by Vicki Carstens
# You can download the paper here: ling.auf.net//lingbuzz/001432
#
# Head Movement in Problems of Projection, by Vicki Carstens, Norbert Hornstein, T. Daniel Seely
# You can download the paper here: ling.auf.net//lingbuzz/001892
#
# Passing on the contrast: Systematic symmetric contrast in subordinate gapping-like ellipsis in Chinese, by Yu Cao
# You can download the paper here: ling.auf.net//lingbuzz/002840
#
# The reliability of acceptability judgments across languages, by Tal Linzen, Yohei Oseki
# You can download the paper here: ling.auf.net//lingbuzz/002854
#
# Spanish aspectual se as an indirect object reflexive: the import of atelicity, bare nouns, and leísta PCC repairs, by Jonathan MacDonald
# You can download the paper here: ling.auf.net//lingbuzz/002873
#
# Gesture for Linguists: A Handy Primer, by Natasha Abner, Kensy Cooperrider, Susan Goldin-Meadow
# You can download the paper here: ling.auf.net//lingbuzz/002875
#
# The Clitic Binding Restriction Revisited: Evidence for Antilogophoricity, by Isabelle Charnavel, Victoria Mateu
# You can download the paper here: ling.auf.net//lingbuzz/002748
#
# A Spanning Account of Denominals in English and Romanian, by Adina Camelia Bleotu
# You can download the paper here: ling.auf.net//lingbuzz/002911
#
# On Phrase Structure building: How your theory of labeling gives away your theory of mind, by Diego Krivochen
# You can download the paper here: ling.auf.net//lingbuzz/002026
#
# Complex predicate formation via voice incorporation, by Susi Wurmbrand
# You can download the paper here: ling.auf.net//lingbuzz/001968
#
# Correlates of ergativity in Mayan, by Judith Aissen
# You can download the paper here: ling.auf.net//lingbuzz/003092
#
# All for one: anaphoric one and its relation to numeral one, by Adele Goldberg, Laura Michaelis
# You can download the paper here: ling.auf.net//lingbuzz/002671
#
# No Clash Constraint in Nominal RNR Number Agreement, by Zheng Shen
# You can download the paper here: ling.auf.net//lingbuzz/002675
#
# A Typology of Negative Polarity Items, by Chris Collins, Paul Postal
# You can download the paper here: ling.auf.net//lingbuzz/002677
#
# Double Modals beyond the South: Would Might, by Chris Collins, John Singler
# You can download the paper here: ling.auf.net//lingbuzz/002678
#
# Enclisis/proclis alternations in Romance: allomorphies 1 and (re)ordering, by Rita Manzini, Leonardo Savoia
# You can download the paper here: ling.auf.net//lingbuzz/002679
#
# Person restrictions in South Baffin Inuktitut: An argument for feature movement, by Michelle Yuan
# You can download the paper here: ling.auf.net//lingbuzz/002686
#
# Closest conjunct agreement is an illusion: Evidence from gender agreement in Serbo-Croatian, by Andrew Murphy, Zorica Puskar
# You can download the paper here: ling.auf.net//lingbuzz/002689
#
# Across-the-Board Phenomena, by Mark de Vries
# You can download the paper here: ling.auf.net//lingbuzz/002435
#
# Verb-stranding verb phrase ellipsis in Japanese, by Kenshi Funakoshi
# You can download the paper here: ling.auf.net//lingbuzz/002691
#
# TP is a phase in relative clauses, by Amy Rose Deal
# You can download the paper here: ling.auf.net//lingbuzz/002693
#
# Exploring Syntax from the Interfaces, by Yoshiyuki Shibata
# You can download the paper here: ling.auf.net//lingbuzz/002694
#
# Resumptivity and Two Types of A'-dependencies in the Minimalist Program, by Victor Pan
# You can download the paper here: ling.auf.net//lingbuzz/002417
#
# Towards resolving the countercyclicity of the EPP, by Thomas McFadden, Sandhya Sundaresan
# You can download the paper here: ling.auf.net//lingbuzz/002698
#
# A uniform syntax for phrasal movement: A Dinka Bor case study, by Coppe van Urk
# You can download the paper here: ling.auf.net//lingbuzz/002699
#
# Licensing without Case, by Theodore Levin
# You can download the paper here: ling.auf.net//lingbuzz/002695
#
# Structure Removal: An Argument for Feature-Driven Merge, by Gereon Mueller
# You can download the paper here: ling.auf.net//lingbuzz/002704
#
# Pronominal Clitics in Old Romanian: the Tobler–Mussafia Law, by Alexandru Nicolae
# You can download the paper here: ling.auf.net//lingbuzz/002556
#
# More misrepresentation: a response to Behme and Evans 2015, by David Adger
# You can download the paper here: ling.auf.net//lingbuzz/002544
#
# The inflected infinitive in Romance, by Kim Groothuis
# You can download the paper here: ling.auf.net//lingbuzz/002561
#
# Do we need abstract Case?, by Michelle Sheehan, Jenneke van der Wal
# You can download the paper here: ling.auf.net//lingbuzz/002594
#
# Interpreting questions under attitudes, by Wataru Uegaki
# You can download the paper here: ling.auf.net//lingbuzz/002617
#
# Syntactic Learning from Ambiguous Evidence: Errors and End-States [Dissertation], by Isaac Gould
# You can download the paper here: ling.auf.net//lingbuzz/002625
#
# Inverse Marking in Plains Cree, by Yuriy Kushnir
# You can download the paper here: ling.auf.net//lingbuzz/002646
#
# Reformulative appositions and clausal ellipsis, by James Griffiths
# You can download the paper here: ling.auf.net//lingbuzz/002668
#
# Deriving prosodic structures [phd], by Guliz Gunes
# You can download the paper here: ling.auf.net//lingbuzz/002560
#
# Building a nonfinite domain: the syntax of gerund clauses in Brazilian Portuguese, by Suzana Fong
# You can download the paper here: ling.auf.net//lingbuzz/002715
#
# Split intransitivity in English, by James Baker
# You can download the paper here: ling.auf.net//lingbuzz/002786
#
# The Breton inflectional impersonal, by Milan Rezac, Melanie Jouitteau
# You can download the paper here: ling.auf.net//lingbuzz/002803
#
# Finiteness in Sundanese, by Eri Kurniawan
# You can download the paper here: ling.auf.net//lingbuzz/002886
#
# Object Suffixes as Incorporated Pronouns in Seereer, by Nico Baier
# You can download the paper here: ling.auf.net//lingbuzz/003311
#
# More on 'have' and 'need', by Claire Halpert, Michael Diercks
# You can download the paper here: ling.auf.net//lingbuzz/003525
#
# The Morphological Expression of Plurality and Pluractionality in Mandarin, by Niina Zhang
# You can download the paper here: ling.auf.net//lingbuzz/002568
#
# Tsez Syntax: A Description, by Maria Polinsky
# You can download the paper here: ling.auf.net//lingbuzz/002315
#
# On the syntactic specialization of Romanian demonstratives and the grammaticalization of the article cel, by Alexandru Nicolae
# You can download the paper here: ling.auf.net//lingbuzz/002438
#
# Free Indirect Discourse and the syntax of the left periphery, by Alessandra Giorgi
# You can download the paper here: ling.auf.net//lingbuzz/002588
#
# The processing of long-distance dependencies in Niuean, by Nicholas Longenbaugh, Maria Polinsky
# You can download the paper here: ling.auf.net//lingbuzz/002589
#
# The Linker in the Khoisan Languages, by Chris Collins
# You can download the paper here: ling.auf.net//lingbuzz/002191
#
# Minimalism and the Design of the Language Faculty, by Iain Mobbs
# You can download the paper here: ling.auf.net//lingbuzz/002305
#
# Does relativized minimality account for wh-island amelioration?, by Emily Atkinson, Aaron Apple, Kyle Rawlins, Akira Omaki
# You can download the paper here: ling.auf.net//lingbuzz/002490
#
# Verb Stems in Jóola Eegimaa: Stem-internal movement and compositional interpretation, by Ken Safir, Mamadou Bassene
# You can download the paper here: ling.auf.net//lingbuzz/002494
#
# Discourse and the syntax of the left periphery, by Alessandra Giorgi
# You can download the paper here: ling.auf.net//lingbuzz/002543
#
# Adjectival and Genitival Modification in Definite Noun Phrases in Icelandic - A Tale of Outsiders and Inside Jobs, by Alexander Pfaff
# You can download the paper here: ling.auf.net//lingbuzz/002555
#
# Possible and impossible cases of possessive perfect, by Eugenia Romanova
# You can download the paper here: ling.auf.net//lingbuzz/002687
#
# The domain of Finiteness: Anchoring without Tense in copular amalgam sentences, by Teresa O'Neill
# You can download the paper here: ling.auf.net//lingbuzz/002702
#
# Movement Transformations in Non-Native Englishes: a Comparative Analysis of Cameroon English (CamE) and Nigerian English (NigE), by Leonel Tadjo Fongang
# You can download the paper here: ling.auf.net//lingbuzz/002810
#
# Towards a Geometrical Syntax: a Formalization of Radical Minimalism, by Diego Krivochen
# You can download the paper here: ling.auf.net//lingbuzz/001444
#
# On appositives [PhD], by James Griffiths
# You can download the paper here: ling.auf.net//lingbuzz/002478
#
# An Interface Approach to Binding: Spelling Out referential expressions as a function of syntactic-semantic construal, by Diego Krivochen
# You can download the paper here: ling.auf.net//lingbuzz/002488
#
# On (Non-)Compositionality of Prefixed Verbs, by Petr Biskup
# You can download the paper here: ling.auf.net//lingbuzz/002493
#
# Against ellipsis: Arguments for the direct licensing of `non-canonical' coordinations, by Yusuke Kubota, Bob Levine
# You can download the paper here: ling.auf.net//lingbuzz/002214
#
# Gradient and Iconic Features in ASL [Squib], by Philippe Schlenker
# You can download the paper here: ling.auf.net//lingbuzz/001918
#
# Beyond the Pirahã Controversy - A Review of Dan Everett’s Language the Cultural Tool., by Christina Behme
# You can download the paper here: ling.auf.net//lingbuzz/001696
#
# ATB-topicalization in Mandarin Chinese:  an Intersective Operator Analysis, by Victor Pan
# You can download the paper here: ling.auf.net//lingbuzz/002391
#
# Wh-ex-situ in Mandarin Chinese: Mapping Between Information Structure and Split CP, by Victor Pan
# You can download the paper here: ling.auf.net//lingbuzz/002390
#
# Names and the Mass-Count Distinction, by Friederike Moltmann
# You can download the paper here: ling.auf.net//lingbuzz/002393
#
# Agreement and semantic concord: a spurious unification, by Omer Preminger, Maria Polinsky
# You can download the paper here: ling.auf.net//lingbuzz/002363
#
# (De)-constructing Evidentiality, by Rose-Marie Dechaine, Clare Cook, Jeffrey Muehlbauer, Ryan Waldie
# You can download the paper here: ling.auf.net//lingbuzz/002089
#
# Deducing the Generalized XP Constraint from phasal spell-out, by Zeljko Boskovic
# You can download the paper here: ling.auf.net//lingbuzz/002396
#
# Mythical Myths: a commentary on Vyvyan Evans' "the Language Myth", by David Adger
# You can download the paper here: ling.auf.net//lingbuzz/002397
#
# Topic Prominence, by Waltraud Paul, John Whitman
# You can download the paper here: ling.auf.net//lingbuzz/002399
#
# Reflexivization patterns in ditransitive sentences. Consequences for thematic theory (in Spanish), by Sonia Kaminszczik, Andrés Saab
# You can download the paper here: ling.auf.net//lingbuzz/002285
#
# Dissertation Title: Learning and Unlearning Object Drop in Anaphoric and Non-anaphoric Contexts in L2 English, by Chi Wai, Patrick LEE
# You can download the paper here: ling.auf.net//lingbuzz/002408
#
# Anti-agreeing infinitives in Old Hungarian, by Éva Dékány
# You can download the paper here: ling.auf.net//lingbuzz/002409
#
# Long-distance genitive of negation in Lithuanian, by Peter Arkadiev
# You can download the paper here: ling.auf.net//lingbuzz/002413
#
# AP-Adjacency as a Precedence Constraint, by Zoe Belk, Ad Neeleman
# You can download the paper here: ling.auf.net//lingbuzz/002059
#
# Disentangling perceptual uncertainty and incrementality in syntactic processing: Click monitoring via ERPs, by David J. Lobina, Josep Demestre, José E. García-Albea
# You can download the paper here: ling.auf.net//lingbuzz/002434
#
# Dependency and discourse-configurationality: A study of Avar, by Pavel Rudnev
# You can download the paper here: ling.auf.net//lingbuzz/002465
#
# Parameterising ergativity: an inherent case approach, by Michelle Sheehan
# You can download the paper here: ling.auf.net//lingbuzz/002464
#
# Verb-third in early West Germanic: a comparative perspective, by George Walkden
# You can download the paper here: ling.auf.net//lingbuzz/002516
#
# Linkers in Aromanian in comparison to Albanian (and Romanian), by Rita Manzini, Savoia Leonardo M.
# You can download the paper here: ling.auf.net//lingbuzz/002526
#
# Jespersen’s Cycle = Minimize Structure + Feature Economy, by Anne Breitbarth
# You can download the paper here: ling.auf.net//lingbuzz/002537
#
# Morphological case mismatches under sluicing, by Luis Vicente
# You can download the paper here: ling.auf.net//lingbuzz/002558
#
# On the distribution of headless XP movement and ellipsis: a reply to Funakoshi, by Luis Vicente
# You can download the paper here: ling.auf.net//lingbuzz/002559
#
# On the Syntactic Representation of Events, by Tal Siloni
# You can download the paper here: ling.auf.net//lingbuzz/002590
#
# Click Pronouns in N|uu, by Chris Collins
# You can download the paper here: ling.auf.net//lingbuzz/002309
#
# Phase-Head Initiated Structure Building, by Jae-Young Shim
# You can download the paper here: ling.auf.net//lingbuzz/002316
#
# A force-theoretic framework for event structure, by Bridget Copley, Heidi Harley
# You can download the paper here: ling.auf.net//lingbuzz/002010
#
# Causation in Grammatical Structures (TOC and Introduction), by Bridget Copley, Fabienne Martin
# You can download the paper here: ling.auf.net//lingbuzz/002401
#
# Case stacking in nanosyntax, by Anke Himmelreich
# You can download the paper here: ling.auf.net//lingbuzz/002474
#
# Precede-and-command revisited revisited, by Jan-Wouter Zwart
# You can download the paper here: ling.auf.net//lingbuzz/002126
#
# "Quantification at the Syntax-Semantics Interface: Greek 'every' NPs", by Anna-Maria Margariti
# You can download the paper here: ling.auf.net//lingbuzz/002771
#
# Prosodic Phrasing and the That-Trace Effect, by Yosuke Sato, Yoshihito Dobashi
# You can download the paper here: ling.auf.net//lingbuzz/002321
#
# A note on someone (else): An island repair solution and its competitors, by Andrés Saab
# You can download the paper here: ling.auf.net//lingbuzz/002322
#
# Case attraction and matching in resumption in relatives. Evidence for top-down derivation, by Doreen Georgi, Martin Salzmann
# You can download the paper here: ling.auf.net//lingbuzz/002324
#
# Syntax, by David Adger
# You can download the paper here: ling.auf.net//lingbuzz/002243
#
# Finiteness in Mandarin Chinese and the basic syntax of kěnéng, by Victor Pan
# You can download the paper here: ling.auf.net//lingbuzz/002329
#
# Some Consequences of Simplest Merge and φ-Defectiveness in Japanese, by Yohei Oseki, Yoichi Miyamoto
# You can download the paper here: ling.auf.net//lingbuzz/002334
#
# Ergativity Splits in Punjabi and Kurdish, by Rita Manzini, Leonardo Savoia, Ludovico Franco
# You can download the paper here: ling.auf.net//lingbuzz/002337
#
# Romanian adnominal locative PPs and Argument Structure, by Ion Giurgea
# You can download the paper here: ling.auf.net//lingbuzz/002335
#
# Multiple instances of agreement in Mi'gmaq verbs, by Michael Hamilton
# You can download the paper here: ling.auf.net//lingbuzz/002303
#
# Phases and idioms, by Kyumin Kim
# You can download the paper here: ling.auf.net//lingbuzz/002405
#
# Information Structure and the Basaá Left Peripheral Syntax, by Paul Roger Bassong
# You can download the paper here: ling.auf.net//lingbuzz/002483
#
# The third reading of the most expensive photo of Abby, by Zheng Shen
# You can download the paper here: ling.auf.net//lingbuzz/003239
#
# Cutting the theory down to size: an essay on eliminative Minimalism, by Diego Krivochen
# You can download the paper here: ling.auf.net//lingbuzz/002090
#
# Movement Out of Focus, by Michael Yoshitaka Erlewine
# You can download the paper here: ling.auf.net//lingbuzz/002210
#
# The semantics of modification: Adjectives, nouns, and order (2014 NYU dissertation), by Timothy Leffel
# You can download the paper here: ling.auf.net//lingbuzz/repo/semanticsArchive/article/001375
#
# The semantics of modification: Adjectives, nouns, and order (2014 NYU dissertation), by Timothy Leffel
# You can download the paper here: ling.auf.net//lingbuzz/002212
#
# Clause typing and feature inheritance of discourse features, by Bethany Lochbihler, Eric Mathieu
# You can download the paper here: ling.auf.net//lingbuzz/002203
#
# Default Ergative, by Yusuke Imanishi
# You can download the paper here: ling.auf.net//lingbuzz/002221
#
# The Syntax and Semantics of Arabic Spatial Ps, by Sameerah Saeed
# You can download the paper here: ling.auf.net//lingbuzz/002223
#
# Sample chapter of "Syntax of Dutch: Nouns and Noun Phrases (volume 1 & 2)", by Hans Broekhuis
# You can download the paper here: ling.auf.net//lingbuzz/001638
#
# Wh-inquiries into Modern Greek and their theoretical import(ance), by Christos Vlachos
# You can download the paper here: ling.auf.net//lingbuzz/002164
#
# Syntactic Buffers, by Gereon Mueller
# You can download the paper here: ling.auf.net//lingbuzz/002229
#
# A cognitively plausible model for grammar induction, by Roni Katzir
# You can download the paper here: ling.auf.net//lingbuzz/001933
#
# Case and Ergativity, by Michelle Sheehan
# You can download the paper here: ling.auf.net//lingbuzz/002236
#
# On two sources of φ-feature valuation and the consequences for syntactic computation: A case study from the Italian nominal inflection, by Ivona Kucerova
# You can download the paper here: ling.auf.net//lingbuzz/002238
#
# On the CP analysis of Persian finite control constructions, by Negin Ilkhanipour
# You can download the paper here: ling.auf.net//lingbuzz/003244
#
# A morphosyntactic condition on sluicing: evidence from Spanish/German code- switching, by Kay-Eduardo Gonzalez, Sergio Ramos
# You can download the paper here: ling.auf.net//lingbuzz/003411
#
# Evaluating learning strategy components: Being fair [Commentary on “Child language acquisition: Why Universal Grammar doesn’t help”], by Lisa Pearl
# You can download the paper here: ling.auf.net//lingbuzz/001940
#
# The Mystery of Language Evolution, by Marc Hauser, Charles Yang, Robert Berwick, Ian Tattersall, Jeffrey Watumull, Noam Chomsky, Richard Lewontin
# You can download the paper here: ling.auf.net//lingbuzz/002083
#
# The importance of not belonging: Paradigmaticity and Latinate nominalizations in Serbo-Croatian, by Marko Simonovic, Boban Arsenijevic
# You can download the paper here: ling.auf.net//lingbuzz/002087
#
# Adjectival and Argumental Small Clauses vs. Free Adverbial Adjuncts - A phase-based approach within the Radical Minimalism, by Peter Kosta
# You can download the paper here: ling.auf.net//lingbuzz/002088
#
# When linguists talk mathematical logic, by David J. Lobina
# You can download the paper here: ling.auf.net//lingbuzz/002093
#
# Inverse agreement and Hungarian verb paradigms, by András Bárány
# You can download the paper here: ling.auf.net//lingbuzz/002092
#
# Sculpting Language: A Review of the David McNeill Gesture Trilogy, by Daniel Everett
# You can download the paper here: ling.auf.net//lingbuzz/002084
#
# A Two-Tiered Theory of Control, by Idan Landau
# ...
#
# 'Default' case in gapping reconsidered, by Andrew Murphy
# You can download the paper here: ling.auf.net//lingbuzz/003339
#
# Two Instances of a Minimalistic Syntactic Engine (Internal and External) are Responsible for A and A-bar Dependencies Respectively., by Sasson  Margaliot
# You can download the paper here: ling.auf.net//lingbuzz/003343
#
# Ban on simultaneous spell-out of multiple features in the CP domain: the case of Arapaho, by Ksenia Bogomolets
# You can download the paper here: ling.auf.net//lingbuzz/003342
#
# Clitic Doubling, Person and Agreement in French Hyper-Complex Inversion (revised version), by Richard Kayne
# You can download the paper here: ling.auf.net//lingbuzz/003344
#
# Syntactic ergativity as case discrimination, by Amy Rose Deal
# You can download the paper here: ling.auf.net//lingbuzz/003129
#
# (Pseudo) noun incorporation and its kin, by Yusuke Imanishi
# You can download the paper here: ling.auf.net//lingbuzz/003346
#
# Nominal Verbs and Transitive Nouns: Vindicating Lexicalism, by Paul Kiparsky
# You can download the paper here: ling.auf.net//lingbuzz/003355
#
# On what projects in Vietnamese, by Nigel Duffield
# You can download the paper here: ling.auf.net//lingbuzz/003439
#
# A Memory Architecture for Merge, by David Adger
# You can download the paper here: ling.auf.net//lingbuzz/003440
#
# Implicit control crosslingusitically, by Marcel Pitteroff, Florian Schäfer
# You can download the paper here: ling.auf.net//lingbuzz/003493
#
# A derivational account of dependent ergative Case: The instrumental voice in Ixil, by Yusuke Imanishi
# You can download the paper here: ling.auf.net//lingbuzz/003345
#
# The Distribution of Negated Quantifier Phrases in English, by Chris Collins
# You can download the paper here: ling.auf.net//lingbuzz/003348
#
# Is Universal Grammar ready for retirement? A short review of a longstanding misinterpretation, by Jose-Luis Mendivil-Giro
# You can download the paper here: ling.auf.net//lingbuzz/003352
#
# Unmarked case in Estonian nominals, by Mark Norris
# You can download the paper here: ling.auf.net//lingbuzz/003351
#
# Verb-Initial Word Orders (Primarily in Austronesian and Mayan Languages), by Lauren Eby Clemens, Maria Polinsky
# You can download the paper here: ling.auf.net//lingbuzz/002004
#
# *ABA in stem-allomorphy and the emptiness of the nominative, by Thomas McFadden
# You can download the paper here: ling.auf.net//lingbuzz/003353
#
# Whose foot is it?  Pronominal Possessives in Pro-drop Languages: An Experimental Study, by Cilene Rodrigues , Lena Dal Pozzo
# You can download the paper here: ling.auf.net//lingbuzz/003357
#
# An unexpected root clause, by Dag Haug, Marius Jøhndal, Per Erik Solberg
# You can download the paper here: ling.auf.net//lingbuzz/003359
#
# On a class of figure reflexives in Romanian, by Alexandra Cornilescu, Alexandru Nicolae
# You can download the paper here: ling.auf.net//lingbuzz/003361
#
# Adverbs and variability in Kaqchikel Agent Focus: A reply to Erlewine (2015), by Robert Henderson, Jessica Coon
# You can download the paper here: ling.auf.net//lingbuzz/002921
#
# Beware Occam’s Syntactic Razor: Morphotactic Analysis and Spanish Mesoclisis, by Karlos Arregi, Andrew Ira Nevins
# You can download the paper here: ling.auf.net//lingbuzz/003365
#
# A Smuggling Approach to the Dative Alternation, by Chris Collins
# You can download the paper here: ling.auf.net//lingbuzz/003370
#
# Graph Transductions and Typological Gaps in Morphological Paradigms, by Thomas Graf
# You can download the paper here: ling.auf.net//lingbuzz/003373
#
# Perspective is syntactic: evidence from anaphora, by Sandhya Sundaresan
# You can download the paper here: ling.auf.net//lingbuzz/002893
#
# How to Make the Most out of Very Little, by Charles Yang
# You can download the paper here: ling.auf.net//lingbuzz/003368
#
# Voice morphology in Japanese argument structures, by Yohei Oseki
# You can download the paper here: ling.auf.net//lingbuzz/003374
#
# Rage against the Machine: Evaluation Metrics in the 21st Century, by Charles Yang
# You can download the paper here: ling.auf.net//lingbuzz/002933
#
# On an Impossible Affix, by İsa Kerem Bayırlı
# You can download the paper here: ling.auf.net//lingbuzz/003376
#
# Using TikZ for linguistic diagrams, by James Crippen
# You can download the paper here: ling.auf.net//lingbuzz/003379
#
# Historical Changes in Basque Dative Alternations: evidence for a derivational analysis, by Javier Ormazabal, Juan Romero
# You can download the paper here: ling.auf.net//lingbuzz/002536
#
# On emphatic affirmative polarity markers and predicates of truth: 'sí' (yes) and 'sí que' (yes that) in Spanish, by Julio Villa-García, Raquel González-Rodríguez
# You can download the paper here: ling.auf.net//lingbuzz/003382
#
# Properties of the Extended VP in Spanish: Agreement, the Structure of INFL and Subjects, by Julio Villa-García
# You can download the paper here: ling.auf.net//lingbuzz/003381
#
# The Syntax of 'Wherewithal', by Richard Kayne
# You can download the paper here: ling.auf.net//lingbuzz/003419
#
# On the Structure of Toponyms, by Francesco-Alessio Francesco Ursini
# You can download the paper here: ling.auf.net//lingbuzz/repo/semanticsArchive/article/001618
#
# On the Polysemy of Spanish Spatial Ps, by Francesco-Alessio Francesco Ursini
# You can download the paper here: ling.auf.net//lingbuzz/003403
#
# Contrastive topicalization in child English: The case of the dative alternation, by Renato Lacerda
# You can download the paper here: ling.auf.net//lingbuzz/002981
#
# The Agreement Hierarchy and Agree, by Peter W. Smith
# You can download the paper here: ling.auf.net//lingbuzz/003194
#
# Literal and Metaphoric Readings in Spatial Prepositions, by Francesco-Alessio Francesco Ursini
# You can download the paper here: ling.auf.net//lingbuzz/003398
#
# Language contact and V3 in Germanic varieties new and old, by George Walkden
# You can download the paper here: ling.auf.net//lingbuzz/003070
#
# Labeling for Linearization, by Yu Cao
# You can download the paper here: ling.auf.net//lingbuzz/003427
#
# Embedded Late Merge and the Theory of Displacement, by Danny Fox
# You can download the paper here: ling.auf.net//lingbuzz/003429
#
# Unifying EPP and comp-trace effects: constraints on silent elements at the edge, by Thomas McFadden, Sandhya Sundaresan
# You can download the paper here: ling.auf.net//lingbuzz/003428
#
# The Autonomy of Syntax, by David Adger
# You can download the paper here: ling.auf.net//lingbuzz/003442
#
# Attributes of Attribution, by Zoe Belk
# You can download the paper here: ling.auf.net//lingbuzz/003452
#
# Subject placement in the history of Latin, by Lieven Danckaert
# You can download the paper here: ling.auf.net//lingbuzz/003481
#
# Passive, by Artemis Alexiadou, Elena Anagnostopoulou, Florian Schäfer
# You can download the paper here: ling.auf.net//lingbuzz/003495
#
# Harmonic syntax of the twelve-bar blues form: A corpus study, by Jonah Katz
# You can download the paper here: ling.auf.net//lingbuzz/003518
#
# Processing Tenses for the Living and the Dead: A Psycholinguistic Investigation of Lifetime Effects in Tensed and “Tenseless” Languages [Thesis], by Sherry Yong Chen
# You can download the paper here: ling.auf.net//lingbuzz/003534
#
# An Alternative Roadmap to Deep Linguistic Intelligence, by Sasson  Margaliot
# You can download the paper here: ling.auf.net//lingbuzz/003431
#
# On the difference between exhaustive and partial control, by Michelle Sheehan
# You can download the paper here: ling.auf.net//lingbuzz/003437
#
# On (Non-)roothood of the Japanese Politeness Marker -Mas- , by Keisuke Yoshimoto
# You can download the paper here: ling.auf.net//lingbuzz/003441
#
# Resumption (resumed Phrases are always moved, even with in-island resumption), by Dominique Sportiche
# You can download the paper here: ling.auf.net//lingbuzz/003443
#
# Relative Clauses, by Dominique Sportiche
# You can download the paper here: ling.auf.net//lingbuzz/003444
#
# Antisymmetry and Morphology. Prefixes vs. Suffixes, by Richard Kayne
# You can download the paper here: ling.auf.net//lingbuzz/003445
#
# Cumulative Effects in Differential Argument Encoding and Long-Distance Extraction: Local Conjunction vs. Harmonic Grammar, by Gereon Mueller
# You can download the paper here: ling.auf.net//lingbuzz/003446
#
# A microparametric approach to the head-initial/head-final parameter, by Guglielmo Cinque
# You can download the paper here: ling.auf.net//lingbuzz/003449
#
# The Generative Word, by Hagit Borer
# You can download the paper here: ling.auf.net//lingbuzz/003450
#
# The position of case markers relative to possessive agreement: variation within Hungarian, by Éva Dékány
# You can download the paper here: ling.auf.net//lingbuzz/003454
#
# Hierarchy effects in copular constructions: The PCC corner of German, by Jessica Coon, Stefan Keine, Michael Wagner
# You can download the paper here: ling.auf.net//lingbuzz/003456
#
# Reflexive verbs in Hebrew: Deep unaccusativity meets lexical semantics, by Itamar Kastner
# You can download the paper here: ling.auf.net//lingbuzz/003457
#
# The Explanatory Power of Linguistic Theory, by Jeffrey Lidz
# You can download the paper here: ling.auf.net//lingbuzz/003459
#
# Why GIVE Does Not Incorporate in Denominal Verbs, by Adina Camelia Bleotu
# You can download the paper here: ling.auf.net//lingbuzz/003178
#
# Decomposed events in real-time: Putting the pieces (back) together, by Sherry Yong Chen, E. Matthew Husband
# You can download the paper here: ling.auf.net//lingbuzz/003464
#
# Upward-Oriented Complementizer Agreement with Subjects and Objects in Kipsigis, by Michael Diercks, Meghana Rao
# You can download the paper here: ling.auf.net//lingbuzz/003466
#
# Articulated definiteness without articles, by Peter Jenks
# You can download the paper here: ling.auf.net//lingbuzz/003467
#
# Some diachronic changes in Yoruba grammar, by Taofeeq Adebayo
# You can download the paper here: ling.auf.net//lingbuzz/003468
#
# Deriving verb-initial word order in Mayan, by Lauren Eby Clemens, Jessica Coon
# You can download the paper here: ling.auf.net//lingbuzz/003067
#
# .Space and the Vision–Language Interface: A Model-Theoretic Approach, by Francesco-Alessio Francesco Ursini
# You can download the paper here: ling.auf.net//lingbuzz/003473
#
# Phy inside psych, by Isabelle Haïk
# You can download the paper here: ling.auf.net//lingbuzz/003474
#
# Grammaticalization and 'lateral' grammaticalization: a new perspective on linguistic interfaces and functional categories, by Keith Tse
# You can download the paper here: ling.auf.net//lingbuzz/003139
#
# φ-features at the syntax-semantics interface: Evidence from nominal inflection, by Ivona Kucerova
# You can download the paper here: ling.auf.net//lingbuzz/003483
#
# Dependent accusative case and caselessness in Moro, by Peter Jenks, Hannah Sande
# You can download the paper here: ling.auf.net//lingbuzz/003499
#
# Clausal comparison without degree abstraction in Mandarin Chinese, by Michael Yoshitaka Erlewine
# You can download the paper here: ling.auf.net//lingbuzz/001687
#
# Movement constraints on the relative order of double topics in Mandarin Chinese, by Sherry Yong Chen
# You can download the paper here: ling.auf.net//lingbuzz/003465
#
# Super Monsters II:  Role Shift, Iconicity and Quotation in Sign Language, by Philippe Schlenker
# You can download the paper here: ling.auf.net//lingbuzz/002074
#
# Incomplete Comparatives as Ellipsis, by Chris Collins
# You can download the paper here: ling.auf.net//lingbuzz/003542
#
# Two kinds of syntactic ergativity in Mayan, by Jamie Douglas, Rodrigo Ranero, Michelle Sheehan
# You can download the paper here: ling.auf.net//lingbuzz/003540
#
# Extraction and licensing in Toba Batak, by Michael Yoshitaka Erlewine
# You can download the paper here: ling.auf.net//lingbuzz/003261
#
# Differential Subject Marking and the Person Licensing Condition, by pritha chandra, Gurmeet Kaur
# You can download the paper here: ling.auf.net//lingbuzz/003550
#
# Pronoun copying in Dinka and the Copy Theory of Movement, by Coppe van Urk
# You can download the paper here: ling.auf.net//lingbuzz/002978
#
# A that-trace effect on ellipsis, by Isabelle Haïk
# You can download the paper here: ling.auf.net//lingbuzz/003484
#
# Covert hyperraising to object, by Amy Rose Deal
# You can download the paper here: ling.auf.net//lingbuzz/003517
#
# In defense of an HPSG-based theory of non-constituent coordination: A reply to Kubota and Levine, by Shuichi Yatabe, Wai Lok Tam
# You can download the paper here: ling.auf.net//lingbuzz/003152
#
# Sentence-Final Aspect Particles as Finite Markers in Mandarin Chinese, by Niina Zhang
# You can download the paper here: ling.auf.net//lingbuzz/003519
#
# Blackholes and subextraction from adjuncts in English and Norwegian, by J.M.M. Brown
# You can download the paper here: ling.auf.net//lingbuzz/003524
#
# The internal syntax of Q-words, by Karen De Clercq
# You can download the paper here: ling.auf.net//lingbuzz/003527
#
# The theory of argument formation—A view from Mandarin and Yi, by Julie Jiang
# You can download the paper here: ling.auf.net//lingbuzz/001882
#
# Agree Probes Down: Anaphoric Feature Valuation and Phase Reference, by Michael Diercks, Marjo van Koppen, Mike Putnam
# You can download the paper here: ling.auf.net//lingbuzz/003539
#
# Arapaho, the English of Algonquian: V-C movement and its effects on agreement paradigms, by Ksenia Bogomolets, Paula Fenger, Adrian Stegovec
# You can download the paper here: ling.auf.net//lingbuzz/003472
#
# Movement from the double object construction is not fully symmetrical, by Anders Holmberg, Michelle Sheehan, Jenneke van der Wal
# You can download the paper here: ling.auf.net//lingbuzz/003075
#
# Ellipsis in the languages of the Caucasus, by David Erschler
# You can download the paper here: ling.auf.net//lingbuzz/003551
#
# Ellipsis in the phrasal comparative: evidence from correlate constraints, by Tatiana Philippova
# You can download the paper here: ling.auf.net//lingbuzz/003552
#
# Parenthesis: syntactic integration or orphanage? (A rejoinder to Ott 2016), by James Griffiths, Mark de Vries
# You can download the paper here: ling.auf.net//lingbuzz/003553
#
# Cognitax Tool Grammar: Re-factoring the Generative Program; A pervasive action dimension for linguistic description, theory and models, by Larry Smith
# You can download the paper here: ling.auf.net//lingbuzz/003212
#
# The Agreement Theta Generalization, by Maria Polinsky, Omer Preminger
# You can download the paper here: ling.auf.net//lingbuzz/003521
#
# On the Subject of Negative Auxiliary Inversion, by Frances Blanchette, Chris Collins
# You can download the paper here: ling.auf.net//lingbuzz/003555
#
# The feature structure of pronouns: a probe into multidimensional paradigms, by Guido Vanden Wyngaerd
# You can download the paper here: ling.auf.net//lingbuzz/003166
#
# Reducing pro and PRO to a single source, by Thomas McFadden, Sandhya Sundaresan
# You can download the paper here: ling.auf.net//lingbuzz/003560
#
# Prosody-Driven Scrambling in Italian, by Vieri Samek-Lodovici
# You can download the paper here: ling.auf.net//lingbuzz/003564
#
# Building verbs in Chuj: Consequences for the nature of roots, by Jessica Coon
# You can download the paper here: ling.auf.net//lingbuzz/003565
#
# On the syntax and semantics of Italian spatial Ps, by Francesco-Alessio Francesco Ursini
# You can download the paper here: ling.auf.net//lingbuzz/003569
#
# Prenominal Possessives in English: What does the Stimulus Look Like?, by Avery Andrews
# You can download the paper here: ling.auf.net//lingbuzz/003568
#
# Gestural Agreement, by Philippe Schlenker, Emmanuel Chemla
# You can download the paper here: ling.auf.net//lingbuzz/003120
#
# Agree Probes Down: Anaphoric Feature Valuation and Phase Reference, by Michael Diercks, Marjo van Koppen, Mike Putnam
# You can download the paper here: ling.auf.net//lingbuzz/003572
#
# The Five Conjugations of Hebrew Verbs, by Sasson  Margaliot
# You can download the paper here: ling.auf.net//lingbuzz/003513
#
# Within Distributed Morphology, the 3-5-Consonantal Bases Cannot Possibly be Considered Roots, by Sasson  Margaliot
# You can download the paper here: ling.auf.net//lingbuzz/003509
#
# Fseq zones and Slavic L>T>N participles, by Lucie Medova, Bartosz Wiland
# You can download the paper here: ling.auf.net//lingbuzz/003259

# %%
a
# Out:
# [<function __main__.<listcomp>.<lambda>>]
